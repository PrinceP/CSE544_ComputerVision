# %%
import cv2
import numpy as np
from skimage.exposure import rescale_intensity
import matplotlib.pyplot as plt
import scipy.stats as st
from PIL import Image
# %matplotlib inline

# %%
im = Image.open("test1_segm.pnm")
im2 = Image.open("test1_bndy.pnm")
im3 = Image.open("test1_filt.pnm")

# %%
im.save("Segment.jpg","JPEG")
im2.save("Boundary.jpg","JPEG")
im3.save("Filtered.jpg","JPEG")

# %%
plt.figure()
image = cv2.imread("AmazonGO.jpg")
plt.imshow(image)


plt.figure()
simage = cv2.imread("Segment.jpg")
plt.imshow(simage)

plt.figure()
bimage = cv2.imread("Boundary.jpg")
plt.imshow(bimage)


plt.figure()
fimage = cv2.imread("Filtered.jpg")
plt.imshow(fimage)

# %%
plt.figure()
bimage = cv2.imread("Boundary.jpg")
plt.imshow(bimage)
